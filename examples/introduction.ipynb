# %% [markdown]
# # Introduction

# %%
import widget_message_speed
import matplotlib.pyplot as plt

# %%
w = widget_message_speed.ExampleWidget()
w.layout.height = '200px'
w
# Out:
# ExampleWidget(layout=Layout(height='200px'))

# %%
_, bins, _ = plt.hist(w.py_ts_times, bins='auto', density=True)
plt.title('python -> typescript')
plt.xlabel('milliseconds')
plt.ylabel('probability')
plt.show()
plt.hist(w.ts_py_times, bins = bins, density=True)
plt.title('typescript -> python')
plt.xlabel('milliseconds')
plt.ylabel('probability')
plt.show()
plt.scatter(w.py_ts_times,w.ts_py_times, alpha=.1, color='k')
plt.xlabel('py -> ts (ms)')
_ = plt.ylabel('ts -> py (ms)')
